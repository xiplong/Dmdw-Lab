# %%
import pandas as pd
dataset = pd.read_csv('Iris.csv')

# %%
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import pandas as pd
dataset =pd.read_csv('iris.data.csv')

# %%
dataset.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %%
import pandas as pd
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
df=pd.read_csv("iris.data.csv",encoding='unicode_escape')
df.head()
# Out:
# C:\Users\Abhik Das\AppData\Local\Temp\ipykernel_30880\1167009694.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
import pandas as pd
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt
plt.style.use('seaborn')
df=pd.read_csv("iris.data.csv",encoding='unicode_escape')
df.head()
# Out:
# C:\Users\Abhik Das\AppData\Local\Temp\ipykernel_30880\484954217.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
import pandas as pd
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
df=pd.read_csv("Iris.csv",encoding='unicode_escape')
df.head()
# Out:
# C:\Users\Abhik Das\AppData\Local\Temp\ipykernel_30880\1104688899.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sb.boxplot(df['Speed'],notch=True,orient='v',color='Green',width=0.74)
      dataset.show()
# Out:
#   Cell In[12], line 2
#     dataset.show()
#     ^
# IndentationError: unexpected indent

# %%
import pandas as pd
dataset = pd.read_csv('Iris.csv')
sb.boxplot(df['Speed'],notch=True,orient='v',color='Green',width=0.74)
      dataset.show()
# Out:
#   Cell In[13], line 4
#     dataset.show()
#     ^
# IndentationError: unexpected indent

# %%
import pandas as pd
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt
df=pd.read_csv("Iris.csv")
sb.boxplot(df['SepalWidthCm'],notch=True,orient='v',color='Green',width=0.74)
plt.show()

# %%
import pandas as pd
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt
df=pd.read_csv("Iris.csv",encoding='unicode_escape')
sb.lmplot(x='SepalLengthCm', y='SepalWidthCm', data=df,hue='PetalLengthCm',fit_reg=True)
plt.show()

# %%
import pandas as pd
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt
df=pd.read_csv("Iris.csv")
sb.boxplot(df['PetalLengthCm'],notch=True,orient='v',color='Green',width=0.74)
plt.show()

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

# Pandas dataframe
data = pd.DataFrame({"Box1": np.random.rand(10), "Box2": np.random.rand(10)})

# Plot the dataframe
ax = data[['Box1', 'Box2']].plot(kind='box', title='boxplot')

# Display the plot
plt.show()
