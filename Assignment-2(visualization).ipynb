# %%
 import pandas as pd
import numpy as np 
import seaborn as sb
df=pd.read_csv("Iris.csv",encoding='unicode_escape')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
 import pandas as pd
import numpy as np 
import seaborn as sb
sb.boxplot(df['SepalLengthCm'],notch=True,orient='v',color='Green',width=0.74)
plt.show()

# %%
import pandas as pd 
dataset =pd.read_csv("Toyota.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0  Price   Age     KM FuelType  HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel  90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel  90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel  90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel  90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel  90       0.0          0  2000
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170

# %%
plt.hist(df['SepalLengthCm'],bins=20,ec='White',color='Blue')
plt.show()

# %%
plt.hist(df['SepalWidthCm'],bins=40,ec='White',color='Blue')
plt.show()

# %%
import pandas as pd 
import numpy as np 
import seaborn as sb
dataset =pd.read_csv("Toyota.csv")
plt.scatter(df['KM'],df['Price'],color=['blue'])
plt.xlabel('KM')
plt.ylabel('Price')
plt.title("KM vs Price")
plt.show()

# %%
import pandas as pd
import numpy as np 
import seaborn as sb
df=pd.read_csv("Toyota.csv",encoding='unicode_escape')
plt.hist(df['CC'],bins=40,ec='White',color='yellow')
plt.show()
